# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagopinzon92/PredictiveSoilMapping/blob/master/Evaluaci%C3%B3n%20formativa%205Ejercicios_KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/akshayrb22/playing-with-data/blob/master/supervised_learning/KNN/KNN.ipynb)

# %% [markdown]
# El algoritmo de K vecinos más cercanos (KNN) es un tipo de algoritmo de aprendizaje automático supervisado.
#
# KNN es extremadamente fácil de implementar en su forma más básica, pero realiza tareas de clasificación bastante complejas.
#
# Es un algoritmo de aprendizaje perezoso, ya que no tiene una fase de entrenamiento especializada.
#
# En su lugar, utiliza todos los datos para el entrenamiento mientras clasifica un nuevo punto o instancia de datos.
#
# KNN es un **algoritmo de aprendizaje no paramétrico, lo que significa que no asume nada sobre los datos subyacentes**.
#
# Esta característica es extremadamente útil, ya que la mayoría de los datos del mundo real no siguen ningún supuesto teórico, como la separabilidad lineal, la distribución uniforme, etc.
#
# ## Ventajas
#
# - Es extremadamente fácil de implementar.
#
# - Como se mencionó anteriormente, es un algoritmo de aprendizaje perezoso y, por lo tanto, no requiere entrenamiento previo para realizar predicciones en tiempo real. Esto hace que el algoritmo KNN sea mucho más rápido que otros algoritmos que requieren entrenamiento, como SVM, regresión lineal, etc.
#
# - Dado que el algoritmo no requiere entrenamiento previo para realizar predicciones, se pueden agregar nuevos datos sin problemas.
#
# - Solo se requieren dos parámetros para implementar KNN: el valor de K y la función de distancia (p. ej., euclidiana o Manhattan, etc.).
#
# ## Desventajas
#
# - El algoritmo KNN no funciona bien con datos de alta dimensión, ya que, con un gran número de dimensiones, le resulta difícil calcular la distancia en cada dimensión.
#
# - El algoritmo KNN tiene un alto coste de predicción para conjuntos de datos grandes. Esto se debe a que, en conjuntos de datos grandes, el coste de calcular la distancia entre un nuevo punto y cada punto existente es mayor.
#
# - Finalmente, el algoritmo KNN no funciona bien con características categóricas, ya que es difícil calcular la distancia entre dimensiones con características categóricas.

# %%
#Importando las librerías necesarias
import pandas as pd
import numpy as np
import math
import operator

# %% [markdown]
# # Importando el Dataset

# %%
url = 'https://raw.githubusercontent.com/melwinlobo18/K-Nearest-Neighbors/master/Dataset/data.csv'
df = pd.read_csv(url)  # Dataset - Datos de cáncer de mama de Wisconsin
df['diagnosis'] = df['diagnosis'].map({
    'M': 1,
    'B': 2
})  # Valores de las etiquetas - 1 para Maligno y 2 para Benigno
labels = df['diagnosis'].tolist()
df['Class'] = labels  #Copiando los valores del diagnóstico a una nueva columna de etiquetas
df = df.drop(['id', 'Unnamed: 32', 'diagnosis'],
             axis=1)  #Borramos las columnas innecesarias
df.head()  #Imprimimos las 5 primeras filas del Dataset
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  Class
# 0          0.4601                  0.11890      1
# 1          0.2750                  0.08902      1
# 2          0.3613                  0.08758      1
# 3          0.6638                  0.17300      1
# 4          0.2364                  0.07678      1
#
# [5 rows x 31 columns]

# %% [markdown]
# # Partición de entrenamiento y de test

# %%
np.random.seed(1)
msk = np.random.rand(
    len(df)) < 0.7  #Un arreglo (vector) que contine True (con probabilidad 0.7) y False
train = df[msk]  #Filas que contienen valores True del arreglo
test = df[~msk]  #Filas que contienen valores False del arreglo
print('Número de observaciones el los datos de entrenamiento: ', len(train))
print('Número de observaciones en los datos de testing: ', len(test))
# Out:
# Número de observaciones el los datos de entrenamiento:  395
# Número de observaciones en los datos de testing:  174

# %%
train.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0           0.1184
# 2        19.69         21.25          130.00     1203.0           0.1096
# 3        11.42         20.38           77.58      386.1           0.1425
# 4        20.29         14.34          135.10     1297.0           0.1003
# 5        12.45         15.70           82.57      477.1           0.1278
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0            0.2776          0.3001              0.14710         0.2419
# 2            0.1599          0.1974              0.12790         0.2069
# 3            0.2839          0.2414              0.10520         0.2597
# 4            0.1328          0.1980              0.10430         0.1809
# 5            0.1700          0.1578              0.08089         0.2087
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
# 5                 0.07613  ...          23.75           103.40       741.6
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
# 5            0.1791             0.5249           0.5355                0.1741
#
#    symmetry_worst  fractal_dimension_worst  Class
# 0          0.4601                  0.11890      1
# 2          0.3613                  0.08758      1
# 3          0.6638                  0.17300      1
# 4          0.2364                  0.07678      1
# 5          0.3985                  0.12440      1
#
# [5 rows x 31 columns]

# %%
test.head()
# Out:
#     radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 1        20.570         17.77          132.90     1326.0          0.08474
# 13       15.850         23.95          103.70      782.7          0.08401
# 20       13.080         15.71           85.63      520.0          0.10750
# 21        9.504         12.44           60.34      273.9          0.10240
# 24       16.650         21.38          110.00      904.6          0.11210
#
#     compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 1            0.07864         0.08690              0.07017         0.1812
# 13           0.10020         0.09938              0.05364         0.1847
# 20           0.12700         0.04568              0.03110         0.1967
# 21           0.06492         0.02956              0.02076         0.1815
# 24           0.14570         0.15250              0.09170         0.1995
#
#     fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 1                  0.05667  ...          23.41           158.80      1956.0
# 13                 0.05338  ...          27.66           112.00       876.5
# 20                 0.06811  ...          20.49            96.09       630.5
# 21                 0.06905  ...          15.66            65.13       314.9
# 24                 0.06330  ...          31.56           177.00      2215.0
#
#     smoothness_worst  compactness_worst  concavity_worst  \
# 1             0.1238             0.1866          0.24160
# 13            0.1131             0.1924          0.23220
# 20            0.1312             0.2776          0.18900
# 21            0.1324             0.1148          0.08867
# 24            0.1805             0.3578          0.46950
#
#     concave points_worst  symmetry_worst  fractal_dimension_worst  Class
# 1                0.18600          0.2750                  0.08902      1
# 13               0.11190          0.2809                  0.06287      1
# 20               0.07283          0.3184                  0.08183      2
# 21               0.06227          0.2450                  0.07773      2
# 24               0.20950          0.3613                  0.09564      1
#
# [5 rows x 31 columns]

# %% [markdown]
# # Distancia Euclidiana
#
# Se utiliza para medir la distancia entre las muestras p y q en un espacio de características de n dimensiones:
#
# <img src="https://drive.google.com/uc?export=view&id=13p3YOEqHybBrN8P5wpsPwBC6-7v3N98f">
#
# Por ejemplo, imagínelo como una línea "recta que conecta" en un espacio de características 2D:
#
# <img src="https://drive.google.com/uc?export=view&id=1Qc0nBRJTWBrJeKZvvj8dVk7YZJrvMpn8">

# %%
def euclideanDistance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
        print("voy a imprimir la distancia en la func. euclideanDistance")
        print(distance)
    return math.sqrt(distance)

# %% [markdown]
# # Calculando los vecinos más cercanos
#
# Supongamos que nuestros datos están dispersos como se muestra a continuación. Los círculos rojos representan la malignidad y los verdes, el benignidad.
#
# <img src="https://drive.google.com/uc?export=view&id=1oEbIjxE0Ysdo5fEeNU5CGo4ruP544Ywz">
#
# En este ejemplo estamos calculando k = 3 vecinos más cercanos, por lo que la curva de ajuste se verá así:
#
# <img src="https://drive.google.com/uc?export=view&id=1amCw22CqF0ideK9VWNIWQAASpZOWGPwi">

# %%
def getNeighbors(trainingSet, testInstance, k):
    distances = []  #Lista que guarda todos los valores de distancias
    length = len(testInstance) - 1
    print("voy a imprimir length")
    print(length)
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x], length)  #Calculando las distancias euclídeas
        distances.append((trainingSet[x],dist))  #Añadimos los valores de la distancia al final de la lista
    distances.sort(key=operator.itemgetter(1))  #Ordenamos basados en los valores de la distancia
    neighbors = []  #Lista para guardar a todos los vecinos
    print(f"Seleccionando los {k} vecinos más cercanos")  # ← print añadido
    for x in range(k):
        neighbors.append(distances[x][0])  #El número de vecinos depende del valor de K
    return neighbors

# %% [markdown]
# La función calcula la distancia euclídea entre una instancia de prueba y todas las del conjunto de entrenamiento.
# Ordena esas distancias de menor a mayor y selecciona los k ejemplos más cercanos.
# Devuelve una lista con los k vecinos más próximos para usarlos en la predicción del algoritmo KNN.

# %%
def getResponse(neighbors):
    classVotes = {}  #Diccionario para guardar las etiquetas y su conteo
    for x in range(len(neighbors)):
        response = neighbors[x][-1]  #Valores de las etiquetas de los vecinos
        if response in classVotes:
            classVotes[
                response] += 1  #Si el valor de la etiqueta ya esta presente incrementamos 1
        else:
            classVotes[
                response] = 1  #Si el valor de la etiqueta no esta presente añadimos la etiqueta al diccionario
    sortedVotes = sorted(
        classVotes.items(), key=operator.itemgetter(1), reverse=True
    )  #Ordenamos el diccionario basados en el valor de conteo en orden descendente
    return sortedVotes[0][
        0]  #Retornamos la etiqueta con el número más alto de ocurrencias

# %% [markdown]
# # Calculando la exactitud
#
# La exactitud es una métrica que informalmente se refiere a la fracción de predicciones correctas de nuestro modelo. Formalmente, la precisión se define de la siguiente manera:
#
# <img src="https://drive.google.com/uc?export=view&id=1gk-T6kanOB6mM_bs54jgyMs0Bu93V4sh">

# %%
def getAccuracy(testSet, predictions):
    correct = 0  #Variable para guardar las predicciones correctas
    print(f"Evaluando {len(testSet)} instancias de prueba...")  # ← print añadido
    for x in range(len(testSet)):
        if testSet[x][-1] is predictions[x]:  #Validamos que los valores predichos sean los mismos que el valor de la etiqueta
            correct += 1  #Incrementado cuando ambos valores son los mismos
    accuracy = (correct / float(len(testSet))) * 100.0
    print(f"Predicciones correctas: {correct} de {len(testSet)} → Precisión: {accuracy:.2f}%")
    return accuracy  #Exactitud = Número de predicciones correctas / Número total de predicciones

# %% [markdown]
# Compara las etiquetas reales del conjunto de prueba con las predicciones hechas por el modelo KNN.
# Cuenta cuántas predicciones coinciden exactamente con la clase verdadera.
# Calcula y devuelve el porcentaje de aciertos (precisión) del algoritmo sobre el test set.

# %% [markdown]
# # Implementación en un dataset mas pequeño

# %%
trainSet = [[5, 1, 1, 1, 2, 1, 3, 2, 1, 2],
            [10, 10, 10, 10, 5, 10, 10, 10, 7, 4]]
testInstance = [4, 8, 6, 4, 3, 4, 10, 6, 1, 2]
k = 1

print("Instancia de prueba:", testInstance)
print(f"Valor de k: {k}\n")

neighbors = getNeighbors(trainSet, testInstance, k)
print("Vecino más cercano encontrado:", neighbors)
print("Clase predicha para la instancia de prueba →", neighbors[0][-1])
# Out:
# Instancia de prueba: [4, 8, 6, 4, 3, 4, 10, 6, 1, 2]
# Valor de k: 1
#
# voy a imprimir length
# 9
# voy a imprimir la distancia en la func. euclideanDistance
# 1
# voy a imprimir la distancia en la func. euclideanDistance
# 50
# voy a imprimir la distancia en la func. euclideanDistance
# 75
# voy a imprimir la distancia en la func. euclideanDistance
# 84
# voy a imprimir la distancia en la func. euclideanDistance
# 85
# voy a imprimir la distancia en la func. euclideanDistance
# 94
# voy a imprimir la distancia en la func. euclideanDistance
# 143
# voy a imprimir la distancia en la func. euclideanDistance
# 159
# voy a imprimir la distancia en la func. euclideanDistance
# 159
# voy a imprimir la distancia en la func. euclideanDistance
# 36
# voy a imprimir la distancia en la func. euclideanDistance
# 40
# voy a imprimir la distancia en la func. euclideanDistance
# 56
# voy a imprimir la distancia en la func. euclideanDistance
# 92
# voy a imprimir la distancia en la func. euclideanDistance
# 96
# voy a imprimir la distancia en la func. euclideanDistance
# 132
# voy a imprimir la distancia en la func. euclideanDistance
# 132
# voy a imprimir la distancia en la func. euclideanDistance
# 148
# voy a imprimir la distancia en la func. euclideanDistance
# 184
# Seleccionando los 1 vecinos más cercanos
# Vecino más cercano encontrado: [[5, 1, 1, 1, 2, 1, 3, 2, 1, 2]]
# Clase predicha para la instancia de prueba → 2

# %%
neighbors = [[5, 1, 1, 1, 2, 1, 3, 2, 1, 2],
             [3, 1, 1, 1, 2, 1, 2, 3, 1, 2],
             [10, 10, 10, 10, 5, 10, 10, 10, 7, 4]]

print("Vecinos recibidos:", neighbors)
print("Clases de los vecinos:", [vecino[-1] for vecino in neighbors])

response = getResponse(neighbors)

print("Clase predicha por getResponse →", response)
# Out:
# Vecinos recibidos: [[5, 1, 1, 1, 2, 1, 3, 2, 1, 2], [3, 1, 1, 1, 2, 1, 2, 3, 1, 2], [10, 10, 10, 10, 5, 10, 10, 10, 7, 4]]
# Clases de los vecinos: [2, 2, 4]
# Clase predicha por getResponse → 2

# %%
testSet = [[5, 1, 1, 1, 2, 1, 3, 2, 1, 2],
           [3, 1, 1, 1, 2, 1, 2, 3, 1, 2],
           [10, 10, 10, 10, 5, 10, 10, 10, 7, 4]]
predictions = [2, 2, 2]

# Prints añadidos (solo información que ya existe)
print("Conjunto de prueba (etiquetas reales):", [inst[-1] for inst in testSet])
print("Predicciones del modelo:          ", predictions)
print("Comparación uno a uno:            ",
      [f"Real: {testSet[i][-1]} → Pred: {predictions[i]} → {'Correcto' if testSet[i][-1]==predictions[i] else 'Incorrecto'}"
       for i in range(len(testSet))])

accuracy = getAccuracy(testSet, predictions)
print(f"Precisión final: {accuracy:.2f}%")
# Out:
# Conjunto de prueba (etiquetas reales): [2, 2, 4]
# Predicciones del modelo:           [2, 2, 2]
# Comparación uno a uno:             ['Real: 2 → Pred: 2 → Correcto', 'Real: 2 → Pred: 2 → Correcto', 'Real: 4 → Pred: 2 → Incorrecto']
# Evaluando 3 instancias de prueba...
# Predicciones correctas: 2 de 3 → Precisión: 66.67%
# Precisión final: 66.67%

# %% [markdown]
# # Implementación en el dataset importado

# %%
predictions = []  #Lista para guardar los valores predichos
k = 3  # 3-Nearest Neighbors
trainingSet = train.values.tolist()  #Lista conteniendo los datos de entrenamiento
testSet = test.values.tolist()  #Lista conteniendo los datos de testing
for x in range(len(testSet)):
    neighbors = getNeighbors(trainingSet, testSet[x], k)
    result = getResponse(neighbors)
    predictions.append(result)  # Guardando los valores predichos.
    print('> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 702564.973594601
# voy a imprimir la distancia en la func. euclideanDistance
# 702691.311194601
# voy a imprimir la distancia en la func. euclideanDistance
# 712910.499294601
# voy a imprimir la distancia en la func. euclideanDistance
# 2438980.939294601
# voy a imprimir la distancia en la func. euclideanDistance
# 2438980.9442549855
# voy a imprimir la distancia en la func. euclideanDistance
# 2438981.2232502257
# voy a imprimir la distancia en la func. euclideanDistance
# 2438981.6038158354
# voy a imprimir la distancia en la func. euclideanDistance
# 2438981.6353220856
# voy a imprimir la distancia en la func. euclideanDistance
# 2438981.6670773258
# voy a imprimir la distancia en la func. euclideanDistance
# 2438981.667676596
# voy a imprimir la distancia en la func. euclideanDistance
# 1.0201000000000031
# voy a imprimir la distancia en la func. euclideanDistance
# 19.768999999999988
# voy a imprimir la distancia en la func. euclideanDistance
# 173.52899999999977
# voy a imprimir la distancia en la func. euclideanDistance
# 5649.5289999999995
# voy a imprimir la distancia en la func. euclideanDistance
# 5649.52921316
# voy a imprimir la distancia en la func. euclideanDistance
# 5649.5610004841
# voy a imprimir la distancia en la func. euclideanDistance
# 5649.5955592941
# voy a imprimir la distancia en la func. euclideanDistance
# 5649.599325571
# voy a imprimir la distancia en la func. euclideanDistance
# 5649.604713131
# voy a imprimir la distancia en la func. euclideanDistance
# 5649.6049771934995
# voy a imprimir la distancia en la func. euclideanDistance
# 5649.671851153499
# voy a imprimir la distancia en la func. euclideanDistance
# 5649.720251153499
# voy a imprimir la distancia en la func. euclideanDistance
# 5657.876987153499
# voy a imprimir la distancia en la func. euclideanDistance
# 6560.278587153499
# voy a imprimir la distancia en la func. euclideanDistance
# 6560.278616076383
# voy a imprimir la distancia en la func. euclideanDistance
# 6560.280404520483
# voy a imprimir la distancia en la func. euclideanDistance
# 6560.280892930483
# voy a imprimir la distancia en la func. euclideanDistance
# 6560.2808956529825
# voy a imprimir la distancia en la func. euclideanDistance
# 6560.2809423018825
# voy a imprimir la distancia en la func. euclideanDistance
# 6560.280961468767
# voy a imprimir la distancia en la func. euclideanDistance
# 6578.7709614687665
# voy a imprimir la distancia en la func. euclideanDistance
# 6650.342561468767
# voy a imprimir la distancia en la func. euclideanDistance
# 8657.382561468765
# voy a imprimir la distancia en la func. euclideanDistance
# 168657.38256146875
# voy a imprimir la distancia en la func. euclideanDistance
# 168657.38271030874
# voy a imprimir la distancia en la func. euclideanDistance
# 168657.85001926875
# voy a imprimir la distancia en la func. euclideanDistance
# 168658.14270026874
# voy a imprimir la distancia en la func. euclideanDistance
# 168658.15671882874
# voy a imprimir la distancia en la func. euclideanDistance
# 168658.18890318874
# voy a imprimir la distancia en la func. euclideanDistance
# 168658.19288353683
# voy a imprimir la distancia en la func. euclideanDistance
# 54.612100000000005
# voy a imprimir la distancia en la func. euclideanDistance
# 71.2585
# voy a imprimir la distancia en la func. euclideanDistance
# 3207.2585
# voy a imprimir la distancia en la func. euclideanDistance
# 531881.6685
# voy a imprimir la distancia en la func. euclideanDistance
# 531881.6693934122
# voy a imprimir la distancia en la func. euclideanDistance
# 531881.7199959147
# voy a imprimir la distancia en la func. euclideanDistance
# 531881.8247646572
# voy a imprimir la distancia en la func. euclideanDistance
# 531881.8420095996
# voy a imprimir la distancia en la func. euclideanDistance
# 531881.8480624396
# voy a imprimir la distancia en la func. euclideanDistance
# 531881.848267502
# voy a imprimir la distancia en la func. euclideanDistance
# 531882.116177262
# voy a imprimir la distancia en la func. euclideanDistance
# 531882.176202262
# voy a imprimir la distancia en la func. euclideanDistance
# 531902.0499662621
# voy a imprimir la distancia en la func. euclideanDistance
# 536613.4995662621
# voy a imprimir la distancia en la func. euclideanDistance
# 536613.4995668307
# voy a imprimir la distancia en la func. euclideanDistance
# 536613.5024288667
# voy a imprimir la distancia en la func. euclideanDistance
# 536613.5055727116
# voy a imprimir la distancia en la func. euclideanDistance
# 536613.5056765273
# voy a imprimir la distancia en la func. euclideanDistance
# 536613.5057719802
# voy a imprimir la distancia en la func. euclideanDistance
# 536613.5057909637
# voy a imprimir la distancia en la func. euclideanDistance
# 536743.2378909637
# voy a imprimir la distancia en la func. euclideanDistance
# 536770.1739909637
# voy a imprimir la distancia en la func. euclideanDistance
# 545476.9300909637
# voy a imprimir la distancia en la func. euclideanDistance
# 1957058.5400909637
# voy a imprimir la distancia en la func. euclideanDistance
# 1957058.5413941736
# voy a imprimir la distancia en la func. euclideanDistance
# 1957059.1217334135
# voy a imprimir la distancia en la func. euclideanDistance
# 1957059.7612535036
# voy a imprimir la distancia en la func. euclideanDistance
# 1957059.8032580062
# voy a imprimir la distancia en la func. euclideanDistance
# 1957059.8302524963
# voy a imprimir la distancia en la func. euclideanDistance
# 1957059.8334019508
# voy a imprimir la distancia en la func. euclideanDistance
# 57.76000000000002
# voy a imprimir la distancia en la func. euclideanDistance
# 75.4
# voy a imprimir la distancia en la func. euclideanDistance
# 3380.5000999999993
# voy a imprimir la distancia en la func. euclideanDistance
# 558107.5400999999
# voy a imprimir la distancia en la func. euclideanDistance
# 558107.541263492
# voy a imprimir la distancia en la func. euclideanDistance
# 558107.5924616049
# voy a imprimir la distancia en la func. euclideanDistance
# 558107.7076132405
# voy a imprimir la distancia en la func. euclideanDistance
# 558107.7256712249
# voy a imprimir la distancia en la func. euclideanDistance
# 558107.7310002248
# voy a imprimir la distancia en la func. euclideanDistance
# 558107.7312457737
# voy a imprimir la distancia en la func. euclideanDistance
# 558107.9464489837
# voy a imprimir la distancia en la func. euclideanDistance
# 558108.0782179837
# voy a imprimir la distancia en la func. euclideanDistance
# 558125.0114429838
# voy a imprimir la distancia en la func. euclideanDistance
# 562353.9123429838
# voy a imprimir la distancia en la func. euclideanDistance
# 562353.9123432027
# voy a imprimir la distancia en la func. euclideanDistance
# 562353.915110594
# voy a imprimir la distancia en la func. euclideanDistance
# 562353.9193994032
# voy a imprimir la distancia en la func. euclideanDistance
# 562353.9195055756
# voy a imprimir la distancia en la func. euclideanDistance
# 562353.9196285637
# voy a imprimir la distancia en la func. euclideanDistance
# 562353.9196503819
# voy a imprimir la distancia en la func. euclideanDistance
# 562483.8796503819
# voy a imprimir la distancia en la func. euclideanDistance
# 562540.7312503819
# voy a imprimir la distancia en la func. euclideanDistance
# 571290.4628503819
# voy a imprimir la distancia en la func. euclideanDistance
# 1993346.7128503819
# voy a imprimir la distancia en la func. euclideanDistance
# 1993346.714716622
# voy a imprimir la distancia en la func. euclideanDistance
# 1993347.290494062
# voy a imprimir la distancia en la func. euclideanDistance
# 1993348.0898731083
# voy a imprimir la distancia en la func. euclideanDistance
# 1993348.1322226324
# voy a imprimir la distancia en la func. euclideanDistance
# 1993348.1639422425
# voy a imprimir la distancia en la func. euclideanDistance
# 1993348.1676742306
# voy a imprimir la distancia en la func. euclideanDistance
# 117.61402500000001
# voy a imprimir la distancia en la func. euclideanDistance
# 118.89092500000001
# voy a imprimir la distancia en la func. euclideanDistance
# 6268.587324999998
# voy a imprimir la distancia en la func. euclideanDistance
# 955139.397325
# voy a imprimir la distancia en la func. euclideanDistance
# 955139.3987659616
# voy a imprimir la distancia en la func. euclideanDistance
# 955139.4520069093
# voy a imprimir la distancia en la func. euclideanDistance
# 955139.5648961894
# voy a imprimir la distancia en la func. euclideanDistance
# 955139.5849382543
# voy a imprimir la distancia en la func. euclideanDistance
# 955139.5909600144
# voy a imprimir la distancia en la func. euclideanDistance
# 955139.591073224
# voy a imprimir la distancia en la func. euclideanDistance
# 955139.891267634
# voy a imprimir la distancia en la func. euclideanDistance
# 955139.899731634
# voy a imprimir la distancia en la func. euclideanDistance
# 955160.411572634
# voy a imprimir la distancia en la func. euclideanDistance
# 960776.4151726341
# voy a imprimir la distancia en la func. euclideanDistance
# 960776.4151726384
# voy a imprimir la distancia en la func. euclideanDistance
# 960776.4175618928
# voy a imprimir la distancia en la func. euclideanDistance
# 960776.4207733817
# voy a imprimir la distancia en la func. euclideanDistance
# 960776.420884389
# voy a imprimir la distancia en la func. euclideanDistance
# 960776.420940639
# voy a imprimir la distancia en la func. euclideanDistance
# 960776.4209559818
# voy a imprimir la distancia en la func. euclideanDistance
# 961003.5258559819
# voy a imprimir la distancia en la func. euclideanDistance
# 961009.7758559819
# voy a imprimir la distancia en la func. euclideanDistance
# 974598.3407559819
# voy a imprimir la distancia en la func. euclideanDistance
# 3138733.550755982
# voy a imprimir la distancia en la func. euclideanDistance
# 3138733.5536719817
# voy a imprimir la distancia en la func. euclideanDistance
# 3138734.1270238217
# voy a imprimir la distancia en la func. euclideanDistance
# 3138734.8783660615
# voy a imprimir la distancia en la func. euclideanDistance
# 3138734.925169057
# voy a imprimir la distancia en la func. euclideanDistance
# 3138734.956356617
# voy a imprimir la distancia en la func. euclideanDistance
# 3138734.9590491895
# voy a imprimir la distancia en la func. euclideanDistance
# 12.390400000000023
# voy a imprimir la distancia en la func. euclideanDistance
# 17.142800000000022
# voy a imprimir la distancia en la func. euclideanDistance
# 852.3527999999994
# voy a imprimir la distancia en la func. euclideanDistance
# 112475.1628
# voy a imprimir la distancia en la func. euclideanDistance
# 112475.1631541924
# voy a imprimir la distancia en la func. euclideanDistance
# 112475.1907101924
# voy a imprimir la distancia en la func. euclideanDistance
# 112475.2535606824
# voy a imprimir la distancia en la func. euclideanDistance
# 112475.2612502185
# voy a imprimir la distancia en la func. euclideanDistance
# 112475.26489837849
# voy a imprimir la distancia en la func. euclideanDistance
# 112475.26495240099
# voy a imprimir la distancia en la func. euclideanDistance
# 112475.306202011
# voy a imprimir la distancia en la func. euclideanDistance
# 112475.502451011
# voy a imprimir la distancia en la func. euclideanDistance
# 112475.580292011
# voy a imprimir la distancia en la func. euclideanDistance
# 113315.420692011
# voy a imprimir la distancia en la func. euclideanDistance
# 113315.42069693052
# voy a imprimir la distancia en la func. euclideanDistance
# 113315.42224850263
# voy a imprimir la distancia en la func. euclideanDistance
# 113315.42418098422
# voy a imprimir la distancia en la func. euclideanDistance
# 113315.42418522782
# voy a imprimir la distancia en la func. euclideanDistance
# 113315.42419301192
# voy a imprimir la distancia en la func. euclideanDistance
# 113315.42419613774
# voy a imprimir la distancia en la func. euclideanDistance
# 113323.15259613775
# voy a imprimir la distancia en la func. euclideanDistance
# 113347.45749613775
# voy a imprimir la distancia en la func. euclideanDistance
# 114403.70749613775
# voy a imprimir la distancia en la func. euclideanDistance
# 144332.70749613777
# voy a imprimir la distancia en la func. euclideanDistance
# 144332.70752113775
# voy a imprimir la distancia en la func. euclideanDistance
# 144333.09652282775
# voy a imprimir la distancia en la func. euclideanDistance
# 144333.55187786775
# voy a imprimir la distancia en la func. euclideanDistance
# 144333.56386811775
# voy a imprimir la distancia en la func. euclideanDistance
# 144333.57546740776
# voy a imprimir la distancia en la func. euclideanDistance
# 144333.57658296777
# voy a imprimir la distancia en la func. euclideanDistance
# 38.44000000000001
# voy a imprimir la distancia en la func. euclideanDistance
# 43.91560000000001
# voy a imprimir la distancia en la func. euclideanDistance
# 2333.5380999999993
# voy a imprimir la distancia en la func. euclideanDistance
# 385370.74809999997
# voy a imprimir la distancia en la func. euclideanDistance
# 385370.75038962247
# voy a imprimir la distancia en la func. euclideanDistance
# 385370.8009111754
# voy a imprimir la distancia en la func. euclideanDistance
# 385370.901172065
# voy a imprimir la distancia en la func. euclideanDistance
# 385370.9192973019
# voy a imprimir la distancia en la func. euclideanDistance
# 385370.9240583019
# voy a imprimir la distancia en la func. euclideanDistance
# 385370.9243088908
# voy a imprimir la distancia en la func. euclideanDistance
# 385371.16883914085
# voy a imprimir la distancia en la func. euclideanDistance
# 385371.63642158086
# voy a imprimir la distancia en la func. euclideanDistance
# 385387.99844658084
# voy a imprimir la distancia en la func. euclideanDistance
# 389704.4884465808
# voy a imprimir la distancia en la func. euclideanDistance
# 389704.4884479404
# voy a imprimir la distancia en la func. euclideanDistance
# 389704.4904540845
# voy a imprimir la distancia en la func. euclideanDistance
# 389704.49310221605
# voy a imprimir la distancia en la func. euclideanDistance
# 389704.49320768897
# voy a imprimir la distancia en la func. euclideanDistance
# 389704.49329049897
# voy a imprimir la distancia en la func. euclideanDistance
# 389704.4933089288
# voy a imprimir la distancia en la func. euclideanDistance
# 389811.4089089288
# voy a imprimir la distancia en la func. euclideanDistance
# 389866.7625089288
# voy a imprimir la distancia en la func. euclideanDistance
# 396956.4025089288
# voy a imprimir la distancia en la func. euclideanDistance
# 1577221.3625089289
# voy a imprimir la distancia en la func. euclideanDistance
# 1577221.366515819
# voy a imprimir la distancia en la func. euclideanDistance
# 1577221.887944229
# voy a imprimir la distancia en la func. euclideanDistance
# 1577222.514416479
# voy a imprimir la distancia en la func. euclideanDistance
# 1577222.558252276
# voy a imprimir la distancia en la func. euclideanDistance
# 1577222.5885979158
# voy a imprimir la distancia en la func. euclideanDistance
# 1577222.5921215254
# voy a imprimir la distancia en la func. euclideanDistance
# 81.00000000000003
# voy a imprimir la distancia en la func. euclideanDistance
# 201.3409
# voy a imprimir la distancia en la func. euclideanDistance
# 4586.4293
# voy a imprimir la distancia en la func. euclideanDistance
# 731001.7192999999
# voy a imprimir la distancia en la func. euclideanDistance
# 731001.7203705983
# voy a imprimir la distancia en la func. euclideanDistance
# 731001.7680910007
# voy a imprimir la distancia en la func. euclideanDistance
# 731001.8690433536
# voy a imprimir la distancia en la func. euclideanDistance
# 731001.8870610466
# voy a imprimir la distancia en la func. euclideanDistance
# 731001.8948226565
# voy a imprimir la distancia en la func. euclideanDistance
# 731001.8949565215
# voy a imprimir la distancia en la func. euclideanDistance
# 731002.1913278814
# voy a imprimir la distancia en la func. euclideanDistance
# 731002.8792322414
# voy a imprimir la distancia en la func. euclideanDistance
# 731022.8511932414
# voy a imprimir la distancia en la func. euclideanDistance
# 736400.1400932415
# voy a imprimir la distancia en la func. euclideanDistance
# 736400.1400932764
# voy a imprimir la distancia en la func. euclideanDistance
# 736400.1420797613
# voy a imprimir la distancia en la func. euclideanDistance
# 736400.1446168981
# voy a imprimir la distancia en la func. euclideanDistance
# 736400.1447004926
# voy a imprimir la distancia en la func. euclideanDistance
# 736400.1447044926
# voy a imprimir la distancia en la func. euclideanDistance
# 736400.1447161685
# voy a imprimir la distancia en la func. euclideanDistance
# 736568.3656161685
# voy a imprimir la distancia en la func. euclideanDistance
# 736805.5256161685
# voy a imprimir la distancia en la func. euclideanDistance
# 747193.2120161685
# voy a imprimir la distancia en la func. euclideanDistance
# 2505204.0220161686
# voy a imprimir la distancia en la func. euclideanDistance
# 2505204.0229648086
# voy a imprimir la distancia en la func. euclideanDistance
# 2505204.4953460987
# voy a imprimir la distancia en la func. euclideanDistance
# 2505205.0619033887
# voy a imprimir la distancia en la func. euclideanDistance
# 2505205.095071083
# voy a imprimir la distancia en la func. euclideanDistance
# 2505205.102762373
# voy a imprimir la distancia en la func. euclideanDistance
# 2505205.1048208103
# voy a imprimir la distancia en la func. euclideanDistance
# 54.16960000000002
# voy a imprimir la distancia en la func. euclideanDistance
# 138.8096
# voy a imprimir la distancia en la func. euclideanDistance
# 2972.242499999999
# voy a imprimir la distancia en la func. euclideanDistance
# 524400.6525000001
# voy a imprimir la distancia en la func. euclideanDistance
# 524400.6537222017
# voy a imprimir la distancia en la func. euclideanDistance
# 524400.6776542917
# voy a imprimir la distancia en la func. euclideanDistance
# 524400.7403544517
# voy a imprimir la distancia en la func. euclideanDistance
# 524400.7556487205
# voy a imprimir la distancia en la func. euclideanDistance
# 524400.7619848805
# voy a imprimir la distancia en la func. euclideanDistance
# 524400.7620189862
# voy a imprimir la distancia en la func. euclideanDistance
# 524400.9600439862
# voy a imprimir la distancia en la func. euclideanDistance
# 524401.5707862362
# voy a imprimir la distancia en la func. euclideanDistance
# 524407.3451952362
# voy a imprimir la distancia en la func. euclideanDistance
# 528302.3532952361
# voy a imprimir la distancia en la func. euclideanDistance
# 528302.3532977737
# voy a imprimir la distancia en la func. euclideanDistance
# 528302.3533226738
# voy a imprimir la distancia en la func. euclideanDistance
# 528302.3533547095
# voy a imprimir la distancia en la func. euclideanDistance
# 528302.3533634711
# voy a imprimir la distancia en la func. euclideanDistance
# 528302.3534271515
# voy a imprimir la distancia en la func. euclideanDistance
# 528302.3534309461
# voy a imprimir la distancia en la func. euclideanDistance
# 528408.4434309461
# voy a imprimir la distancia en la func. euclideanDistance
# 528602.209830946
# voy a imprimir la distancia en la func. euclideanDistance
# 533446.3698309461
# voy a imprimir la distancia en la func. euclideanDistance
# 1716102.619830946
# voy a imprimir la distancia en la func. euclideanDistance
# 1716102.621846956
# voy a imprimir la distancia en la func. euclideanDistance
# 1716102.713959206
# voy a imprimir la distancia en la func. euclideanDistance
# 1716102.794104816
# voy a imprimir la distancia en la func. euclideanDistance
# 1716102.810823306
# voy a imprimir la distancia en la func. euclideanDistance
# 1716102.826248946
# voy a imprimir la distancia en la func. euclideanDistance
# 1716102.826249756
# voy a imprimir la distancia en la func. euclideanDistance
# 119.50862400000004
# voy a imprimir la distancia en la func. euclideanDistance
# 245.62152399999997
# voy a imprimir la distancia en la func. euclideanDistance
# 6492.9431239999985
# voy a imprimir la distancia en la func. euclideanDistance
# 964346.633124
# voy a imprimir la distancia en la func. euclideanDistance
# 964346.6343273962
# voy a imprimir la distancia en la func. euclideanDistance
# 964346.6839315946
# voy a imprimir la distancia en la func. euclideanDistance
# 964346.7972378867
# voy a imprimir la distancia en la func. euclideanDistance
# 964346.818621392
# voy a imprimir la distancia en la func. euclideanDistance
# 964346.823762282
# voy a imprimir la distancia en la func. euclideanDistance
# 964346.8237987637
# voy a imprimir la distancia en la func. euclideanDistance
# 964346.9715621236
# voy a imprimir la distancia en la func. euclideanDistance
# 964347.0516511237
# voy a imprimir la distancia en la func. euclideanDistance
# 964359.2806601237
# voy a imprimir la distancia en la func. euclideanDistance
# 968615.5382601237
# voy a imprimir la distancia en la func. euclideanDistance
# 968615.5382799974
# voy a imprimir la distancia en la func. euclideanDistance
# 968615.5406819775
# voy a imprimir la distancia en la func. euclideanDistance
# 968615.5443859171
# voy a imprimir la distancia en la func. euclideanDistance
# 968615.5445473596
# voy a imprimir la distancia en la func. euclideanDistance
# 968615.5445609756
# voy a imprimir la distancia en la func. euclideanDistance
# 968615.544571254
# voy a imprimir la distancia en la func. euclideanDistance
# 968828.412671254
# voy a imprimir la distancia en la func. euclideanDistance
# 969047.452671254
# voy a imprimir la distancia en la func. euclideanDistance
# 981927.4327712541
# voy a imprimir la distancia en la func. euclideanDistance
# 3057832.072771254
# voy a imprimir la distancia en la func. euclideanDistance
# 3057832.073457694
# voy a imprimir la distancia en la func. euclideanDistance
# 3057832.6249124543
# voy a imprimir la distancia en la func. euclideanDistance
# 3057833.3898551064
# voy a imprimir la distancia en la func. euclideanDistance
# 3057833.4474551063
# voy a imprimir la distancia en la func. euclideanDistance
# 3057833.4580641063
# voy a imprimir la distancia en la func. euclideanDistance
# 3057833.460111669
# voy a imprimir la distancia en la func. euclideanDistance
# 9.0
# voy a imprimir la distancia en la func. euclideanDistance
# 45.0
# voy a imprimir la distancia en la func. euclideanDistance
# 490.20999999999975
# voy a imprimir la distancia en la func. euclideanDistance
# 81430.46
# voy a imprimir la distancia en la func. euclideanDistance
# 81430.4606205081
# voy a imprimir la distancia en la func. euclideanDistance
# 81430.46648806811
# voy a imprimir la distancia en la func. euclideanDistance
# 81430.48547690811
# voy a imprimir la distancia en la func. euclideanDistance
# 81430.48816014812
# voy a imprimir la distancia en la func. euclideanDistance
# 81430.49307415812
# voy a imprimir la distancia en la func. euclideanDistance
# 81430.49308661903
# voy a imprimir la distancia en la func. euclideanDistance
# 81430.53425502902
# voy a imprimir la distancia en la func. euclideanDistance
# 81430.55115502902
# voy a imprimir la distancia en la func. euclideanDistance
# 81430.55199602903
# voy a imprimir la distancia en la func. euclideanDistance
# 81779.49439602903
# voy a imprimir la distancia en la func. euclideanDistance
# 81779.49439608856
# voy a imprimir la distancia en la func. euclideanDistance
# 81779.49447125745
# voy a imprimir la distancia en la func. euclideanDistance
# 81779.49449892505
# voy a imprimir la distancia en la func. euclideanDistance
# 81779.49454078595
# voy a imprimir la distancia en la func. euclideanDistance
# 81779.49458316604
# voy a imprimir la distancia en la func. euclideanDistance
# 81779.49460932927
# voy a imprimir la distancia en la func. euclideanDistance
# 81796.88350932927
# voy a imprimir la distancia en la func. euclideanDistance
# 81908.18600932928
# voy a imprimir la distancia en la func. euclideanDistance
# 83589.18600932928
# voy a imprimir la distancia en la func. euclideanDistance
# 231045.18600932928
# voy a imprimir la distancia en la func. euclideanDistance
# 231045.18797181928
# voy a imprimir la distancia en la func. euclideanDistance
# 231045.33975997928
# voy a imprimir la distancia en la func. euclideanDistance
# 231045.5180128193
# voy a imprimir la distancia en la func. euclideanDistance
# 231045.5222899793
# voy a imprimir la distancia en la func. euclideanDistance
# 231045.5541879393
# voy a imprimir la distancia en la func. euclideanDistance
# 231045.5541904993
# voy a imprimir la distancia en la func. euclideanDistance
# 80.64040000000004
# voy a imprimir la distancia en la func. euclideanDistance
# 204.9629
# voy a imprimir la distancia en la func. euclideanDistance
# 4265.2013
# voy a imprimir la distancia en la func. euclideanDistance
# 737343.6413
# voy a imprimir la distancia en la func. euclideanDistance
# 737343.64130009
# voy a imprimir la distancia en la func. euclideanDistance
# 737343.65786378
# voy a imprimir la distancia en la func. euclideanDistance
# 737343.72006414
# voy a imprimir la distancia en la func. euclideanDistance
# 737343.7293493897
# voy a imprimir la distancia en la func. euclideanDistance
# 737343.7312853896
# voy a imprimir la distancia en la func. euclideanDistance
# 737343.7312911018
# voy a imprimir la distancia en la func. euclideanDistance
# 737343.8310839118
# voy a imprimir la distancia en la func. euclideanDistance
# 737343.8521089118
# voy a imprimir la distancia en la func. euclideanDistance
# 737351.3871339118
# voy a imprimir la distancia en la func. euclideanDistance
# 740758.4440339118
# voy a imprimir la distancia en la func. euclideanDistance
# 740758.4440990044
# voy a imprimir la distancia en la func. euclideanDistance
# 740758.4449704348
# voy a imprimir la distancia en la func. euclideanDistance
# 740758.4454352683
# voy a imprimir la distancia en la func. euclideanDistance
# 740758.4454384012
# voy a imprimir la distancia en la func. euclideanDistance
# 740758.4454651301
# voy a imprimir la distancia en la func. euclideanDistance
# 740758.4454660672
# voy a imprimir la distancia en la func. euclideanDistance
# 740911.7098660672
# voy a imprimir la distancia en la func. euclideanDistance
# 741108.2702660671
# voy a imprimir la distancia en la func. euclideanDistance
# 750412.8018660671
# voy a imprimir la distancia en la func. euclideanDistance
# 2422003.2118660673
# voy a imprimir la distancia en la func. euclideanDistance
# 2422003.2120350674
# voy a imprimir la distancia en la func. euclideanDistance
# 2422003.5487831575
# voy a imprimir la distancia en la func. euclideanDistance
# 2422003.9333071676
# voy a imprimir la distancia en la func. euclideanDistance
# 2422003.9485347276
# voy a imprimir la distancia en la func. euclideanDistance
# 2422003.9688980174
# voy a imprimir la distancia en la func. euclideanDistance
# 2422003.9698777073
# voy a imprimir la distancia en la func. euclideanDistance
# 73.27360000000004
# voy a imprimir la distancia en la func. euclideanDistance
# 74.68970000000004
# voy a imprimir la distancia en la func. euclideanDistance
# 4075.2522
# voy a imprimir la distancia en la func. euclideanDistance
# 668463.2622
# voy a imprimir la distancia en la func. euclideanDistance
# 668463.2631168783
# voy a imprimir la distancia en la func. euclideanDistance
# 668463.3102058783
# voy a imprimir la distancia en la func. euclideanDistance
# 668463.4176128312
# voy a imprimir la distancia en la func. euclideanDistance
# 668463.4340557641
# voy a imprimir la distancia en la func. euclideanDistance
# 668463.4370042541
# voy a imprimir la distancia en la func. euclideanDistance
# 668463.4371779665
# voy a imprimir la distancia en la func. euclideanDistance
# 668463.4515539765
# voy a imprimir la distancia en la func. euclideanDistance
# 668464.5498579765
# voy a imprimir la distancia en la func. euclideanDistance
# 668467.3487869765
# voy a imprimir la distancia en la func. euclideanDistance
# 670169.7363869766
# voy a imprimir la distancia en la func. euclideanDistance
# 670169.7363879665
# voy a imprimir la distancia en la func. euclideanDistance
# 670169.7385067275
# voy a imprimir la distancia en la func. euclideanDistance
# 670169.7417012379
# voy a imprimir la distancia en la func. euclideanDistance
# 670169.741724374
# voy a imprimir la distancia en la func. euclideanDistance
# 670169.7417320469
# voy a imprimir la distancia en la func. euclideanDistance
# 670169.7417373462
# voy a imprimir la distancia en la func. euclideanDistance
# 670317.1213373462
# voy a imprimir la distancia en la func. euclideanDistance
# 670354.2094373462
# voy a imprimir la distancia en la func. euclideanDistance
# 679833.1790373462
# voy a imprimir la distancia en la func. euclideanDistance
# 2250844.7390373466
# voy a imprimir la distancia en la func. euclideanDistance
# 2250844.7427461566
# voy a imprimir la distancia en la func. euclideanDistance
# 2250845.3369404622
# voy a imprimir la distancia en la func. euclideanDistance
# 2250846.1174420337
# voy a imprimir la distancia en la func. euclideanDistance
# 2250846.1613448546
# voy a imprimir la distancia en la func. euclideanDistance
# 2250846.1896697446
# voy a imprimir la distancia en la func. euclideanDistance
# 2250846.1929886565
# voy a imprimir la distancia en la func. euclideanDistance
# 32.262400000000014
# voy a imprimir la distancia en la func. euclideanDistance
# 239.62239999999997
# voy a imprimir la distancia en la func. euclideanDistance
# 2144.9448999999995
# voy a imprimir la distancia en la func. euclideanDistance
# 336344.55490000005
# voy a imprimir la distancia en la func. euclideanDistance
# 336344.55625571246
# voy a imprimir la distancia en la func. euclideanDistance
# 336344.59293179255
# voy a imprimir la distancia en la func. euclideanDistance
# 336344.68055371265
# voy a imprimir la distancia en la func. euclideanDistance
# 336344.6949033567
# voy a imprimir la distancia en la func. euclideanDistance
# 336344.69994435675
# voy a imprimir la distancia en la func. euclideanDistance
# 336344.70012579765
# voy a imprimir la distancia en la func. euclideanDistance
# 336344.93187175767
# voy a imprimir la distancia en la func. euclideanDistance
# 336346.2811863177
# voy a imprimir la distancia en la func. euclideanDistance
# 336361.8521023177
# voy a imprimir la distancia en la func. euclideanDistance
# 340319.5202023177
# voy a imprimir la distancia en la func. euclideanDistance
# 340319.5202128867
# voy a imprimir la distancia en la func. euclideanDistance
# 340319.5221383411
# voy a imprimir la distancia en la func. euclideanDistance
# 340319.524449066
# voy a imprimir la distancia en la func. euclideanDistance
# 340319.5245169801
# voy a imprimir la distancia en la func. euclideanDistance
# 340319.5246552777
# voy a imprimir la distancia en la func. euclideanDistance
# 340319.52466976334
# voy a imprimir la distancia en la func. euclideanDistance
# 340392.79826976336
# voy a imprimir la distancia en la func. euclideanDistance
# 340842.23826976336
# voy a imprimir la distancia en la func. euclideanDistance
# 346112.99826976337
# voy a imprimir la distancia en la func. euclideanDistance
# 1182240.3582697634
# voy a imprimir la distancia en la func. euclideanDistance
# 1182240.3616920135
# voy a imprimir la distancia en la func. euclideanDistance
# 1182240.7086130134
# voy a imprimir la distancia en la func. euclideanDistance
# 1182241.0974899733
# voy a imprimir la distancia en la func. euclideanDistance
# 1182241.1200800634
# voy a imprimir la distancia en la func. euclideanDistance
# 1182241.1396520734
# voy a imprimir la distancia en la func. euclideanDistance
# 1182241.1413552864
# voy a imprimir la distancia en la func. euclideanDistance
# 69.38890000000004
# voy a imprimir la distancia en la func. euclideanDistance
# 69.79850000000003
# voy a imprimir la distancia en la func. euclideanDistance
# 3998.580899999999
# voy a imprimir la distancia en la func. euclideanDistance
# 643358.7409
# voy a imprimir la distancia en la func. euclideanDistance
# 643358.7425654561
# voy a imprimir la distancia en la func. euclideanDistance
# 643358.8016241764
# voy a imprimir la distancia en la func. euclideanDistance
# 643358.9251061365
# voy a imprimir la distancia en la func. euclideanDistance
# 643358.9482101365
# voy a imprimir la distancia en la func. euclideanDistance
# 643358.9530542966
# voy a imprimir la distancia en la func. euclideanDistance
# 643358.9531658102
# voy a imprimir la distancia en la func. euclideanDistance
# 643359.0318460602
# voy a imprimir la distancia en la func. euclideanDistance
# 643363.2425500602
# voy a imprimir la distancia en la func. euclideanDistance
# 643371.5830940602
# voy a imprimir la distancia en la func. euclideanDistance
# 645981.7711940602
# voy a imprimir la distancia en la func. euclideanDistance
# 645981.7711947277
# voy a imprimir la distancia en la func. euclideanDistance
# 645981.7740395633
# voy a imprimir la distancia en la func. euclideanDistance
# 645981.7791047322
# voy a imprimir la distancia en la func. euclideanDistance
# 645981.7793816219
# voy a imprimir la distancia en la func. euclideanDistance
# 645981.7794483708
# voy a imprimir la distancia en la func. euclideanDistance
# 645981.7794576671
# voy a imprimir la distancia en la func. euclideanDistance
# 646132.8235576672
# voy a imprimir la distancia en la func. euclideanDistance
# 646134.7004576672
# voy a imprimir la distancia en la func. euclideanDistance
# 656038.9308576672
# voy a imprimir la distancia en la func. euclideanDistance
# 2248935.340857667
# voy a imprimir la distancia en la func. euclideanDistance
# 2248935.3458674755
# voy a imprimir la distancia en la func. euclideanDistance
# 2248936.0116745164
# voy a imprimir la distancia en la func. euclideanDistance
# 2248936.8928322066
# voy a imprimir la distancia en la func. euclideanDistance
# 2248936.9630572065
# voy a imprimir la distancia en la func. euclideanDistance
# 2248936.9912140463
# voy a imprimir la distancia en la func. euclideanDistance
# 2248936.9944142113
# voy a imprimir la distancia en la func. euclideanDistance
# 60.37290000000002
# voy a imprimir la distancia en la func. euclideanDistance
# 245.33289999999997
# voy a imprimir la distancia en la func. euclideanDistance
# 3518.316999999999
# voy a imprimir la distancia en la func. euclideanDistance
# 578233.927
# voy a imprimir la distancia en la func. euclideanDistance
# 578233.92775076
# voy a imprimir la distancia en la func. euclideanDistance
# 578233.9655071361
# voy a imprimir la distancia en la func. euclideanDistance
# 578234.0513854385
# voy a imprimir la distancia en la func. euclideanDistance
# 578234.0660797269
# voy a imprimir la distancia en la func. euclideanDistance
# 578234.0708683669
# voy a imprimir la distancia en la func. euclideanDistance
# 578234.0709900277
# voy a imprimir la distancia en la func. euclideanDistance
# 578234.4028812378
# voy a imprimir la distancia en la func. euclideanDistance
# 578235.6294374878
# voy a imprimir la distancia en la func. euclideanDistance
# 578256.5783664878
# voy a imprimir la distancia en la func. euclideanDistance
# 583818.7547664877
# voy a imprimir la distancia en la func. euclideanDistance
# 583818.754769207
# voy a imprimir la distancia en la func. euclideanDistance
# 583818.7566719113
# voy a imprimir la distancia en la func. euclideanDistance
# 583818.7581151514
# voy a imprimir la distancia en la func. euclideanDistance
# 583818.7581837098
# voy a imprimir la distancia en la func. euclideanDistance
# 583818.7582359827
# voy a imprimir la distancia en la func. euclideanDistance
# 583818.7582511615
# voy a imprimir la distancia en la func. euclideanDistance
# 583954.4807511616
# voy a imprimir la distancia en la func. euclideanDistance
# 584357.2856511616
# voy a imprimir la distancia en la func. euclideanDistance
# 592707.5900511616
# voy a imprimir la distancia en la func. euclideanDistance
# 2069418.6300511616
# voy a imprimir la distancia en la func. euclideanDistance
# 2069418.6311009217
# voy a imprimir la distancia en la func. euclideanDistance
# 2069418.9996713316
# voy a imprimir la distancia en la func. euclideanDistance
# 2069419.3490705416
# voy a imprimir la distancia en la func. euclideanDistance
# 2069419.3770163504
# voy a imprimir la distancia en la func. euclideanDistance
# 2069419.3887019604
# voy a imprimir la distancia en la func. euclideanDistance
# 2069419.390816121
# voy a imprimir la distancia en la func. euclideanDistance
# 82.99210000000002
# voy a imprimir la distancia en la func. euclideanDistance
# 300.25969999999995
# voy a imprimir la distancia en la func. euclideanDistance
# 4670.7918
# voy a imprimir la distancia en la func. euclideanDistance
# 744442.8018
# voy a imprimir la distancia en la func. euclideanDistance
# 744442.80197424
# voy a imprimir la distancia en la func. euclideanDistance
# 744442.8398901183
# voy a imprimir la distancia en la func. euclideanDistance
# 744442.9288849407
# voy a imprimir la distancia en la func. euclideanDistance
# 744442.9463908768
# voy a imprimir la distancia en la func. euclideanDistance
# 744442.9502101168
# voy a imprimir la distancia en la func. euclideanDistance
# 744442.9502296532
# voy a imprimir la distancia en la func. euclideanDistance
# 744443.2233404132
# voy a imprimir la distancia en la func. euclideanDistance
# 744443.4073814132
# voy a imprimir la distancia en la func. euclideanDistance
# 744461.0894064131
# voy a imprimir la distancia en la func. euclideanDistance
# 749627.8238064131
# voy a imprimir la distancia en la func. euclideanDistance
# 749627.8238088624
# voy a imprimir la distancia en la func. euclideanDistance
# 749627.825444256
# voy a imprimir la distancia en la func. euclideanDistance
# 749627.826321008
# voy a imprimir la distancia en la func. euclideanDistance
# 749627.8263950024
# voy a imprimir la distancia en la func. euclideanDistance
# 749627.8264181386
# voy a imprimir la distancia en la func. euclideanDistance
# 749627.8264247486
# voy a imprimir la distancia en la func. euclideanDistance
# 749805.7820247486
# voy a imprimir la distancia en la func. euclideanDistance
# 750112.7324247486
# voy a imprimir la distancia en la func. euclideanDistance
# 760631.2860247486
# voy a imprimir la distancia en la func. euclideanDistance
# 2592322.846024749
# voy a imprimir la distancia en la func. euclideanDistance
# 2592322.8469127887
# voy a imprimir la distancia en la func. euclideanDistance
# 2592323.2919351985
# voy a imprimir la distancia en la func. euclideanDistance
# 2592323.7531120083
# voy a imprimir la distancia en la func. euclideanDistance
# 2592323.7894746843
# voy a imprimir la distancia en la func. euclideanDistance
# 2592323.802607844
# voy a imprimir la distancia en la func. euclideanDistance
# 2592323.803644684
# voy a imprimir la distancia en la func. euclideanDistance
# 18.922500000000014
# voy a imprimir la distancia en la func. euclideanDistance
# 115.35489999999994
# voy a imprimir la distancia en la func. euclideanDistance
# 1033.4448999999997
# voy a imprimir la distancia en la func. euclideanDistance
# 202814.08490000005
# voy a imprimir la distancia en la func. euclideanDistance
# 202814.08513104005
# voy a imprimir la distancia en la func. euclideanDistance
# 202814.09282233004
# voy a imprimir la distancia en la func. euclideanDistance
# 202814.10915517004
# voy a imprimir la distancia en la func. euclideanDistance
# 202814.11276237364
# voy a imprimir la distancia en la func. euclideanDistance
# 202814.11336753363
# voy a imprimir la distancia en la func. euclideanDistance
# 202814.11338671803
# voy a imprimir la distancia en la func. euclideanDistance
# 202814.28255440804
# voy a imprimir la distancia en la func. euclideanDistance
# 202814.65380089803
# voy a imprimir la distancia en la func. euclideanDistance
# 202821.95460489803
# voy a imprimir la distancia en la func. euclideanDistance
# 205641.564604898
# voy a imprimir la distancia en la func. euclideanDistance
# 205641.56461205363
# voy a imprimir la distancia en la func. euclideanDistance
# 205641.56465938804
# voy a imprimir la distancia en la func. euclideanDistance
# 205641.56475193243
# voy a imprimir la distancia en la func. euclideanDistance
# 205641.56478229252
# voy a imprimir la distancia en la func. euclideanDistance
# 205641.56480245263
# voy a imprimir la distancia en la func. euclideanDistance
# 205641.56480248153
# voy a imprimir la distancia en la func. euclideanDistance
# 205711.28730248153
# voy a imprimir la distancia en la func. euclideanDistance
# 205979.26420248154
# voy a imprimir la distancia en la func. euclideanDistance
# 209885.51420248154
# voy a imprimir la distancia en la func. euclideanDistance
# 986575.2042024815
# voy a imprimir la distancia en la func. euclideanDistance
# 986575.2049477715
# voy a imprimir la distancia en la func. euclideanDistance
# 986575.3829473815
# voy a imprimir la distancia en la func. euclideanDistance
# 986575.5047483814
# voy a imprimir la distancia en la func. euclideanDistance
# 986575.5124046315
# voy a imprimir la distancia en la func. euclideanDistance
# 986575.5183182415
# voy a imprimir la distancia en la func. euclideanDistance
# 986575.519383611
# voy a imprimir la distancia en la func. euclideanDistance
# 71.23360000000002
# voy a imprimir la distancia en la func. euclideanDistance
# 198.92359999999996
# voy a imprimir la distancia en la func. euclideanDistance
# 4019.3996999999986
# voy a imprimir la distancia en la func. euclideanDistance
# 659633.4897
# voy a imprimir la distancia en la func. euclideanDistance
# 659633.4904252249
# voy a imprimir la distancia en la func. euclideanDistance
# 659633.5298751292
# voy a imprimir la distancia en la func. euclideanDistance
# 659633.6337137468
# voy a imprimir la distancia en la func. euclideanDistance
# 659633.6524088397
# voy a imprimir la distancia en la func. euclideanDistance
# 659633.6611137297
# voy a imprimir la distancia en la func. euclideanDistance
# 659633.6611673121
# voy a imprimir la distancia en la func. euclideanDistance
# 659633.9178108721
# voy a imprimir la distancia en la func. euclideanDistance
# 659634.081835872
# voy a imprimir la distancia en la func. euclideanDistance
# 659650.842671872
# voy a imprimir la distancia en la func. euclideanDistance
# 664545.244271872
# voy a imprimir la distancia en la func. euclideanDistance
# 664545.2442744673
# voy a imprimir la distancia en la func. euclideanDistance
# 664545.2462922737
# voy a imprimir la distancia en la func. euclideanDistance
# 664545.2495641138
# voy a imprimir la distancia en la func. euclideanDistance
# 664545.2496958813
# voy a imprimir la distancia en la func. euclideanDistance
# 664545.2497715713
# voy a imprimir la distancia en la func. euclideanDistance
# 664545.2497902942
# voy a imprimir la distancia en la func. euclideanDistance
# 664699.0097902942
# voy a imprimir la distancia en la func. euclideanDistance
# 664832.4122902942
# voy a imprimir la distancia en la func. euclideanDistance
# 674004.3051902942
# voy a imprimir la distancia en la func. euclideanDistance
# 2296061.265190294
# voy a imprimir la distancia en la func. euclideanDistance
# 2296061.267143934
# voy a imprimir la distancia en la func. euclideanDistance
# 2296061.676999974
# voy a imprimir la distancia en la func. euclideanDistance
# 2296062.280262864
# voy a imprimir la distancia en la func. euclideanDistance
# 2296062.323568474
# voy a imprimir la distancia en la func. euclideanDistance
# 2296062.351826084
# voy a imprimir la distancia en la func. euclideanDistance
# 2296062.354007908
# voy a imprimir la distancia en la func. euclideanDistance
# 50.836900000000014
# voy a imprimir la distancia en la func. euclideanDistance
# 284.0097999999999
# voy a imprimir la distancia en la func. euclideanDistance
# 3069.7382
# voy a imprimir la distancia en la func. euclideanDistance
# 519599.4282000001
# voy a imprimir la distancia en la func. euclideanDistance
# 519599.42831449007
# voy a imprimir la distancia en la func. euclideanDistance
# 519599.45439674007
# voy a imprimir la distancia en la func. euclideanDistance
# 519599.54056247167
# voy a imprimir la distancia en la func. euclideanDistance
# 519599.5504309073
# voy a imprimir la distancia en la func. euclideanDistance
# 519599.5542501473
# voy a imprimir la distancia en la func. euclideanDistance
# 519599.5542643602
# voy a imprimir la distancia en la func. euclideanDistance
# 519599.87598020025
# voy a imprimir la distancia en la func. euclideanDistance
# 519600.91985109024
# voy a imprimir la distancia en la func. euclideanDistance
# 519622.72875109024
# voy a imprimir la distancia en la func. euclideanDistance
# 525007.3531510902
# voy a imprimir la distancia en la func. euclideanDistance
# 525007.3531553834
# voy a imprimir la distancia en la func. euclideanDistance
# 525007.355370027
# voy a imprimir la distancia en la func. euclideanDistance
# 525007.358714336
# voy a imprimir la distancia en la func. euclideanDistance
# 525007.3587759427
# voy a imprimir la distancia en la func. euclideanDistance
# 525007.3588151303
# voy a imprimir la distancia en la func. euclideanDistance
# 525007.3588266767
# voy a imprimir la distancia en la func. euclideanDistance
# 525126.3869266767
# voy a imprimir la distancia en la func. euclideanDistance
# 525571.5969266767
# voy a imprimir la distancia en la func. euclideanDistance
# 533610.5125266766
# voy a imprimir la distancia en la func. euclideanDistance
# 1881067.1525266767
# voy a imprimir la distancia en la func. euclideanDistance
# 1881067.1531871667
# voy a imprimir la distancia en la func. euclideanDistance
# 1881067.5353584066
# voy a imprimir la distancia en la func. euclideanDistance
# 1881068.1037236166
# voy a imprimir la distancia en la func. euclideanDistance
# 1881068.1210158665
# voy a imprimir la distancia en la func. euclideanDistance
# 1881068.1284118665
# voy a imprimir la distancia en la func. euclideanDistance
# 1881068.129356814
# voy a imprimir la distancia en la func. euclideanDistance
# 47.61000000000003
# voy a imprimir la distancia en la func. euclideanDistance
# 184.2661
# voy a imprimir la distancia en la func. euclideanDistance
# 2923.7416999999987
# voy a imprimir la distancia en la func. euclideanDistance
# 484420.9517
# voy a imprimir la distancia en la func. euclideanDistance
# 484420.95203488995
# voy a imprimir la distancia en la func. euclideanDistance
# 484420.99101349484
# voy a imprimir la distancia en la func. euclideanDistance
# 484421.0846005412
# voy a imprimir la distancia en la func. euclideanDistance
# 484421.0990967012
# voy a imprimir la distancia en la func. euclideanDistance
# 484421.10351895116
# voy a imprimir la distancia en la func. euclideanDistance
# 484421.10360506957
# voy a imprimir la distancia en la func. euclideanDistance
# 484421.3367974796
# voy a imprimir la distancia en la func. euclideanDistance
# 484421.7577389196
# voy a imprimir la distancia en la func. euclideanDistance
# 484439.4650029196
# voy a imprimir la distancia en la func. euclideanDistance
# 488740.2014029196
# voy a imprimir la distancia en la func. euclideanDistance
# 488740.20141365833
# voy a imprimir la distancia en la func. euclideanDistance
# 488740.2042645776
# voy a imprimir la distancia en la func. euclideanDistance
# 488740.2072011337
# voy a imprimir la distancia en la func. euclideanDistance
# 488740.20725599735
# voy a imprimir la distancia en la func. euclideanDistance
# 488740.20736394945
# voy a imprimir la distancia en la func. euclideanDistance
# 488740.20738567435
# voy a imprimir la distancia en la func. euclideanDistance
# 488856.41578567435
# voy a imprimir la distancia en la func. euclideanDistance
# 489108.9078856743
# voy a imprimir la distancia en la func. euclideanDistance
# 496997.9002856743
# voy a imprimir la distancia en la func. euclideanDistance
# 1784088.1502856743
# voy a imprimir la distancia en la func. euclideanDistance
# 1784088.1523196842
# voy a imprimir la distancia en la func. euclideanDistance
# 1784088.690341934
# voy a imprimir la distancia en la func. euclideanDistance
# 1784089.2748021842
# voy a imprimir la distancia en la func. euclideanDistance
# 1784089.305158277
# voy a imprimir la distancia en la func. euclideanDistance
# 1784089.329775887
# voy a imprimir la distancia en la func. euclideanDistance
# 1784089.332735247
# voy a imprimir la distancia en la func. euclideanDistance
# 23.71690000000001
# voy a imprimir la distancia en la func. euclideanDistance
# 349.5193999999999
# voy a imprimir la distancia en la func. euclideanDistance
# 1740.8093999999996
# voy a imprimir la distancia en la func. euclideanDistance
# 269857.6494
# voy a imprimir la distancia en la func. euclideanDistance
# 269857.64958225
# voy a imprimir la distancia en la func. euclideanDistance
# 269857.67122066
# voy a imprimir la distancia en la func. euclideanDistance
# 269857.72518395
# voy a imprimir la distancia en la func. euclideanDistance
# 269857.7332641621
# voy a imprimir la distancia en la func. euclideanDistance
# 269857.7370218521
# voy a imprimir la distancia en la func. euclideanDistance
# 269857.737079157
# voy a imprimir la distancia en la func. euclideanDistance
# 269858.054048157
# voy a imprimir la distancia en la func. euclideanDistance
# 269859.513070567
# voy a imprimir la distancia en la func. euclideanDistance
# 269880.940711567
# voy a imprimir la distancia en la func. euclideanDistance
# 275115.463211567
# voy a imprimir la distancia en la func. euclideanDistance
# 275115.46321180515
# voy a imprimir la distancia en la func. euclideanDistance
# 275115.46509362955
# voy a imprimir la distancia en la func. euclideanDistance
# 275115.46652322565
# voy a imprimir la distancia en la func. euclideanDistance
# 275115.46655886655
# voy a imprimir la distancia en la func. euclideanDistance
# 275115.46669088665
# voy a imprimir la distancia en la func. euclideanDistance
# 275115.46670632367
# voy a imprimir la distancia en la func. euclideanDistance
# 275191.67960632365
# voy a imprimir la distancia en la func. euclideanDistance
# 275827.7280063237
# ...
# 2575928.4544137553
# voy a imprimir la distancia en la func. euclideanDistance
# 42.90250000000001
# voy a imprimir la distancia en la func. euclideanDistance
# 47.65490000000001
# voy a imprimir la distancia en la func. euclideanDistance
# 2421.2933
# voy a imprimir la distancia en la func. euclideanDistance
# 444114.45330000005
# voy a imprimir la distancia en la func. euclideanDistance
# 444114.4536426201
# voy a imprimir la distancia en la func. euclideanDistance
# 444114.4806699801
# voy a imprimir la distancia en la func. euclideanDistance
# 444114.5747839485
# voy a imprimir la distancia en la func. euclideanDistance
# 444114.5866562301
# voy a imprimir la distancia en la func. euclideanDistance
# 444114.59405223007
# voy a imprimir la distancia en la func. euclideanDistance
# 444114.5941236326
# voy a imprimir la distancia en la func. euclideanDistance
# 444114.7248058826
# voy a imprimir la distancia en la func. euclideanDistance
# 444114.7354148826
# voy a imprimir la distancia en la func. euclideanDistance
# 444123.0528708826
# voy a imprimir la distancia en la func. euclideanDistance
# 447301.7572708826
# voy a imprimir la distancia en la func. euclideanDistance
# 447301.7572714214
# voy a imprimir la distancia en la func. euclideanDistance
# 447301.7584824614
# voy a imprimir la distancia en la func. euclideanDistance
# 447301.761028673
# voy a imprimir la distancia en la func. euclideanDistance
# 447301.7610288174
# voy a imprimir la distancia en la func. euclideanDistance
# 447301.761034771
# voy a imprimir la distancia en la func. euclideanDistance
# 447301.7610355471
# voy a imprimir la distancia en la func. euclideanDistance
# 447410.7546355471
# voy a imprimir la distancia en la func. euclideanDistance
# 447449.8171355471
# voy a imprimir la distancia en la func. euclideanDistance
# 454573.1771355471
# voy a imprimir la distancia en la func. euclideanDistance
# 1696237.6671355471
# voy a imprimir la distancia en la func. euclideanDistance
# 1696237.668808357
# voy a imprimir la distancia en la func. euclideanDistance
# 1696238.0805872472
# voy a imprimir la distancia en la func. euclideanDistance
# 1696238.7303844572
# voy a imprimir la distancia en la func. euclideanDistance
# 1696238.756048497
# voy a imprimir la distancia en la func. euclideanDistance
# 1696238.789794187
# voy a imprimir la distancia en la func. euclideanDistance
# 1696238.7914580111
# voy a imprimir la distancia en la func. euclideanDistance
# 88.36000000000004
# voy a imprimir la distancia en la func. euclideanDistance
# 88.36160000000004
# voy a imprimir la distancia en la func. euclideanDistance
# 4908.886499999999
# voy a imprimir la distancia en la func. euclideanDistance
# 777549.8865
# voy a imprimir la distancia en la func. euclideanDistance
# 777549.8883757561
# voy a imprimir la distancia en la func. euclideanDistance
# 777549.9466593725
# voy a imprimir la distancia en la func. euclideanDistance
# 777550.0701413326
# voy a imprimir la distancia en la func. euclideanDistance
# 777550.0932453326
# voy a imprimir la distancia en la func. euclideanDistance
# 777550.1111210226
# voy a imprimir la distancia en la func. euclideanDistance
# 777550.1113502422
# voy a imprimir la distancia en la func. euclideanDistance
# 777550.2810118522
# voy a imprimir la distancia en la func. euclideanDistance
# 777555.5756128522
# voy a imprimir la distancia en la func. euclideanDistance
# 777569.4959738522
# voy a imprimir la distancia en la func. euclideanDistance
# 781590.3240738523
# voy a imprimir la distancia en la func. euclideanDistance
# 781590.3240750014
# voy a imprimir la distancia en la func. euclideanDistance
# 781590.3268525022
# voy a imprimir la distancia en la func. euclideanDistance
# 781590.3319176711
# voy a imprimir la distancia en la func. euclideanDistance
# 781590.3321945608
# voy a imprimir la distancia en la func. euclideanDistance
# 781590.3322057833
# voy a imprimir la distancia en la func. euclideanDistance
# 781590.332225249
# voy a imprimir la distancia en la func. euclideanDistance
# 781781.324625249
# voy a imprimir la distancia en la func. euclideanDistance
# 781782.579025249
# voy a imprimir la distancia en la func. euclideanDistance
# 793753.127125249
# voy a imprimir la distancia en la func. euclideanDistance
# 2702019.087125249
# voy a imprimir la distancia en la func. euclideanDistance
# 2702019.0923568783
# voy a imprimir la distancia en la func. euclideanDistance
# 2702019.753586064
# voy a imprimir la distancia en la func. euclideanDistance
# 2702020.6347437543
# voy a imprimir la distancia en la func. euclideanDistance
# 2702020.704968754
# voy a imprimir la distancia en la func. euclideanDistance
# 2702020.768523164
# voy a imprimir la distancia en la func. euclideanDistance
# 2702020.7727416665
# voy a imprimir la distancia en la func. euclideanDistance
# 0.10240000000000019
# voy a imprimir la distancia en la func. euclideanDistance
# 18.079999999999988
# voy a imprimir la distancia en la func. euclideanDistance
# 26.49000000000002
# voy a imprimir la distancia en la func. euclideanDistance
# 6750.49
# voy a imprimir la distancia en la func. euclideanDistance
# 6750.49006241
# voy a imprimir la distancia en la func. euclideanDistance
# 6750.49291397
# voy a imprimir la distancia en la func. euclideanDistance
# 6750.49406997
# voy a imprimir la distancia en la func. euclideanDistance
# 6750.49409113
# voy a imprimir la distancia en la func. euclideanDistance
# 6750.49470617
# voy a imprimir la distancia en la func. euclideanDistance
# 6750.4947080469
# voy a imprimir la distancia en la func. euclideanDistance
# 6750.5504984869
# voy a imprimir la distancia en la func. euclideanDistance
# 6750.8742594869
# voy a imprimir la distancia en la func. euclideanDistance
# 6759.7904554869
# voy a imprimir la distancia en la func. euclideanDistance
# 7821.2468554869
# voy a imprimir la distancia en la func. euclideanDistance
# 7821.24685550203
# voy a imprimir la distancia en la func. euclideanDistance
# 7821.24719701243
# voy a imprimir la distancia en la func. euclideanDistance
# 7821.24725001083
# voy a imprimir la distancia en la func. euclideanDistance
# 7821.24734217083
# voy a imprimir la distancia en la func. euclideanDistance
# 7821.24734929973
# voy a imprimir la distancia en la func. euclideanDistance
# 7821.247349300514
# voy a imprimir la distancia en la func. euclideanDistance
# 7823.349849300514
# voy a imprimir la distancia en la func. euclideanDistance
# 7923.549949300514
# voy a imprimir la distancia en la func. euclideanDistance
# 7953.799949300514
# voy a imprimir la distancia en la func. euclideanDistance
# 7957.799949300514
# voy a imprimir la distancia en la func. euclideanDistance
# 7957.8005397905135
# voy a imprimir la distancia en la func. euclideanDistance
# 7958.0025900405135
# voy a imprimir la distancia en la func. euclideanDistance
# 7958.080319480514
# voy a imprimir la distancia en la func. euclideanDistance
# 7958.080436120514
# voy a imprimir la distancia en la func. euclideanDistance
# 7958.093845760513
# voy a imprimir la distancia en la func. euclideanDistance
# 7958.094484333414
# voy a imprimir la distancia en la func. euclideanDistance
# 0.9215999999999949
# voy a imprimir la distancia en la func. euclideanDistance
# 49.085199999999965
# voy a imprimir la distancia en la func. euclideanDistance
# 52.695199999999986
# voy a imprimir la distancia en la func. euclideanDistance
# 45848.6952
# voy a imprimir la distancia en la func. euclideanDistance
# 45848.69524624
# voy a imprimir la distancia en la func. euclideanDistance
# 45848.72119945
# voy a imprimir la distancia en la func. euclideanDistance
# 45848.7327557
# voy a imprimir la distancia en la func. euclideanDistance
# 45848.732927310004
# voy a imprimir la distancia en la func. euclideanDistance
# 45848.73742972001
# voy a imprimir la distancia en la func. euclideanDistance
# 45848.73762376491
# voy a imprimir la distancia en la func. euclideanDistance
# 45848.94012376491
# voy a imprimir la distancia en la func. euclideanDistance
# 45849.05504476491
# voy a imprimir la distancia en la func. euclideanDistance
# 45852.66884576491
# voy a imprimir la distancia en la func. euclideanDistance
# 51106.0192457649
# voy a imprimir la distancia en la func. euclideanDistance
# 51106.019260038185
# voy a imprimir la distancia en la func. euclideanDistance
# 51106.020327367085
# voy a imprimir la distancia en la func. euclideanDistance
# 51106.020695623185
# voy a imprimir la distancia en la func. euclideanDistance
# 51106.020758033184
# voy a imprimir la distancia en la func. euclideanDistance
# 51106.02090444318
# voy a imprimir la distancia en la func. euclideanDistance
# 51106.0209082301
# voy a imprimir la distancia en la func. euclideanDistance
# 51106.1050082301
# voy a imprimir la distancia en la func. euclideanDistance
# 51275.6254082301
# voy a imprimir la distancia en la func. euclideanDistance
# 51617.8754082301
# voy a imprimir la distancia en la func. euclideanDistance
# 94053.8754082301
# voy a imprimir la distancia en la func. euclideanDistance
# 94053.87598423011
# voy a imprimir la distancia en la func. euclideanDistance
# 94054.30737047011
# voy a imprimir la distancia en la func. euclideanDistance
# 94054.5861544701
# voy a imprimir la distancia en la func. euclideanDistance
# 94054.58803803011
# voy a imprimir la distancia en la func. euclideanDistance
# 94054.6291253201
# voy a imprimir la distancia en la func. euclideanDistance
# 94054.63191844261
# voy a imprimir la distancia en la func. euclideanDistance
# 0.22090000000000226
# voy a imprimir la distancia en la func. euclideanDistance
# 1.3872999999999986
# voy a imprimir la distancia en la func. euclideanDistance
# 80.5973000000001
# voy a imprimir la distancia en la func. euclideanDistance
# 96.5973000000001
# voy a imprimir la distancia en la func. euclideanDistance
# 96.5977000000001
# voy a imprimir la distancia en la func. euclideanDistance
# 96.6278369600001
# voy a imprimir la distancia en la func. euclideanDistance
# 96.6708517200001
# voy a imprimir la distancia en la func. euclideanDistance
# 96.6737774481001
# voy a imprimir la distancia en la func. euclideanDistance
# 96.6779376981001
# voy a imprimir la distancia en la func. euclideanDistance
# 96.67815762700009
# voy a imprimir la distancia en la func. euclideanDistance
# 96.67971787700009
# voy a imprimir la distancia en la func. euclideanDistance
# 97.43314187700008
# voy a imprimir la distancia en la func. euclideanDistance
# 97.75690287700009
# voy a imprimir la distancia en la func. euclideanDistance
# 262.1093028770003
# voy a imprimir la distancia en la func. euclideanDistance
# 262.1093034440093
# voy a imprimir la distancia en la func. euclideanDistance
# 262.1106984665093
# voy a imprimir la distancia en la func. euclideanDistance
# 262.1117014554093
# voy a imprimir la distancia en la func. euclideanDistance
# 262.1117014750093
# voy a imprimir la distancia en la func. euclideanDistance
# 262.11171962260926
# voy a imprimir la distancia en la func. euclideanDistance
# 262.1117332165783
# voy a imprimir la distancia en la func. euclideanDistance
# 266.31423321657826
# voy a imprimir la distancia en la func. euclideanDistance
# 267.68313321657826
# voy a imprimir la distancia en la func. euclideanDistance
# 1143.8431332165778
# voy a imprimir la distancia en la func. euclideanDistance
# 9243.843133216578
# voy a imprimir la distancia en la func. euclideanDistance
# 9243.845475776578
# voy a imprimir la distancia en la func. euclideanDistance
# 9244.302316586578
# voy a imprimir la distancia en la func. euclideanDistance
# 9244.683252426577
# voy a imprimir la distancia en la func. euclideanDistance
# 9244.693697266577
# voy a imprimir la distancia en la func. euclideanDistance
# 9244.716649516577
# voy a imprimir la distancia en la func. euclideanDistance
# 9244.719970733477
# voy a imprimir la distancia en la func. euclideanDistance
# 16.0
# voy a imprimir la distancia en la func. euclideanDistance
# 17.5625
# voy a imprimir la distancia en la func. euclideanDistance
# 1028.8024999999998
# voy a imprimir la distancia en la func. euclideanDistance
# 166596.41249999998
# voy a imprimir la distancia en la func. euclideanDistance
# 166596.41360556247
# voy a imprimir la distancia en la func. euclideanDistance
# 166596.44412565246
# voy a imprimir la distancia en la func. euclideanDistance
# 166596.51114968455
# voy a imprimir la distancia en la func. euclideanDistance
# 166596.52094672495
# voy a imprimir la distancia en la func. euclideanDistance
# 166596.52745921497
# voy a imprimir la distancia en la func. euclideanDistance
# 166596.52764635737
# voy a imprimir la distancia en la func. euclideanDistance
# 166596.60033051737
# voy a imprimir la distancia en la func. euclideanDistance
# 166596.87073051737
# voy a imprimir la distancia en la func. euclideanDistance
# 166602.37913951738
# voy a imprimir la distancia en la func. euclideanDistance
# 168021.40803951738
# voy a imprimir la distancia en la func. euclideanDistance
# 168021.40803990053
# voy a imprimir la distancia en la func. euclideanDistance
# 168021.40862893342
# voy a imprimir la distancia en la func. euclideanDistance
# 168021.40919871032
# voy a imprimir la distancia en la func. euclideanDistance
# 168021.4091998552
# voy a imprimir la distancia en la func. euclideanDistance
# 168021.4093010588
# voy a imprimir la distancia en la func. euclideanDistance
# 168021.40930631664
# voy a imprimir la distancia en la func. euclideanDistance
# 168067.10690631665
# voy a imprimir la distancia en la func. euclideanDistance
# 168095.19690631665
# voy a imprimir la distancia en la func. euclideanDistance
# 171447.60690631665
# voy a imprimir la distancia en la func. euclideanDistance
# 657256.6069063167
# voy a imprimir la distancia en la func. euclideanDistance
# 657256.6095175267
# voy a imprimir la distancia en la func. euclideanDistance
# 657256.9216632167
# voy a imprimir la distancia en la func. euclideanDistance
# 657257.2797457767
# voy a imprimir la distancia en la func. euclideanDistance
# 657257.2949240167
# voy a imprimir la distancia en la func. euclideanDistance
# 657257.3298556267
# voy a imprimir la distancia en la func. euclideanDistance
# 657257.3319532666
# voy a imprimir la distancia en la func. euclideanDistance
# 164.86560000000003
# voy a imprimir la distancia en la func. euclideanDistance
# 187.80970000000002
# voy a imprimir la distancia en la func. euclideanDistance
# 8684.962099999999
# voy a imprimir la distancia en la func. euclideanDistance
# 1183740.9621
# voy a imprimir la distancia en la func. euclideanDistance
# 1183740.9663471289
# voy a imprimir la distancia en la func. euclideanDistance
# 1183741.0208133534
# voy a imprimir la distancia en la func. euclideanDistance
# 1183741.1442953134
# voy a imprimir la distancia en la func. euclideanDistance
# 1183741.1673993133
# voy a imprimir la distancia en la func. euclideanDistance
# 1183741.1739603132
# voy a imprimir la distancia en la func. euclideanDistance
# 1183741.1740884555
# voy a imprimir la distancia en la func. euclideanDistance
# 1183741.2898925454
# voy a imprimir la distancia en la func. euclideanDistance
# 1183741.3177815455
# voy a imprimir la distancia en la func. euclideanDistance
# 1183751.7119575455
# voy a imprimir la distancia en la func. euclideanDistance
# 1188250.0968575454
# voy a imprimir la distancia en la func. euclideanDistance
# 1188250.0968579904
# voy a imprimir la distancia en la func. euclideanDistance
# 1188250.1000978767
# voy a imprimir la distancia en la func. euclideanDistance
# 1188250.1051630457
# voy a imprimir la distancia en la func. euclideanDistance
# 1188250.1054399353
# voy a imprimir la distancia en la func. euclideanDistance
# 1188250.1054523257
# voy a imprimir la distancia en la func. euclideanDistance
# 1188250.1054638992
# voy a imprimir la distancia en la func. euclideanDistance
# 1188515.2741198991
# voy a imprimir la distancia en la func. euclideanDistance
# 1188597.1766198992
# voy a imprimir la distancia en la func. euclideanDistance
# 1204332.3702198993
# voy a imprimir la distancia en la func. euclideanDistance
# 3614278.1302198996
# voy a imprimir la distancia en la func. euclideanDistance
# 3614278.1358509012
# voy a imprimir la distancia en la func. euclideanDistance
# 3614278.781720297
# voy a imprimir la distancia en la func. euclideanDistance
# 3614279.662877987
# voy a imprimir la distancia en la func. euclideanDistance
# 3614279.733102987
# voy a imprimir la distancia en la func. euclideanDistance
# 3614279.747889547
# voy a imprimir la distancia en la func. euclideanDistance
# 3614279.7507635793
# > predicted=1.0, actual=1.0

# %% [markdown]
# # Matriz de Confusión
#
# Mide el rendimiento para problemas de clasificación de aprendizaje automático, donde el resultado puede ser de dos o más clases. Es una tabla con cuatro combinaciones diferentes de valores predichos y reales.
#
# <img src="https://drive.google.com/uc?export=view&id=1hYthqmYW82QHRFnIpiGQDLt4r44aurv7">

# %%
print("Confusion Matrix")
y_test = []
for i in testSet:
    y_test.append(i[30])
from sklearn.metrics import confusion_matrix, accuracy_score
res = confusion_matrix(y_test, predictions)
print(res)
# Out:
# Confusion Matrix
# [[ 52   5]
#  [  6 111]]

# %% [markdown]
# # Exactitud

# %%
accuracy = accuracy_score(y_test, predictions) * 100
print('Accuracy: ' + repr(accuracy) + '%')
# Out:
# Accuracy: 93.67816091954023%
